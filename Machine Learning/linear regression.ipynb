# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv(r'E:\github\data science\data-science\Machine Learning\Gold_price_2025 new.csv')
df.head()
# Out:
#         timeOpen      timeClose       timeHigh        timeLow       priceOpen  \
# 0  1753531200000  1753617599999  1753589280000  1753534320000  0,006715796828
# 1  1753444800000  1753531199999  1753499400000  1753451940000  0,006643911641
# 2  1753358400000  1753444799999  1753358880000  1753415760000  0,006750933166
# 3  1753272000000  1753358399999  1753312560000  1753350120000  0,007042174606
# 4  1753185600000  1753271999999  1753253520000  1753265040000  0,007057862602
#
#         priceHigh        priceLow      priceClose  volume
# 0  0,006865782367  0,006714274853  0,006842611523       0
# 1  0,006718620251  0,006642475657  0,006715796828       0
# 2  0,006752793583  0,006642331031  0,006643911641       0
# 3  0,007053935013  0,006749428149  0,006750933166       0
# 4  0,007093906453  0,006988306188  0,007042174606  130,07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 664 entries, 0 to 663
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   timeOpen    664 non-null    int64
#  1   timeClose   664 non-null    int64
#  2   timeHigh    664 non-null    int64
#  3   timeLow     664 non-null    int64
#  4   priceOpen   664 non-null    object
#  5   priceHigh   664 non-null    object
#  6   priceLow    664 non-null    object
#  7   priceClose  664 non-null    object
#  8   volume      664 non-null    object
# dtypes: int64(4), object(5)
# memory usage: 46.8+ KB

# %%
df.columns
# Out:
# Index(['timeOpen', 'timeClose', 'timeHigh', 'timeLow', 'priceOpen',
#        'priceHigh', 'priceLow', 'priceClose', 'volume'],
#       dtype='object')

# %%
df.describe()
# Out:
#            timeOpen     timeClose      timeHigh       timeLow
# count  6.640000e+02  6.640000e+02  6.640000e+02  6.640000e+02
# mean   1.724750e+12  1.724837e+12  1.724798e+12  1.724791e+12
# std    1.663580e+10  1.663580e+10  1.664105e+10  1.663514e+10
# min    1.695902e+12  1.695989e+12  1.695981e+12  1.695935e+12
# 25%    1.710396e+12  1.710482e+12  1.710426e+12  1.710463e+12
# 50%    1.724717e+12  1.724803e+12  1.724755e+12  1.724789e+12
# 75%    1.739124e+12  1.739210e+12  1.739207e+12  1.739183e+12
# max    1.753531e+12  1.753618e+12  1.753589e+12  1.753534e+12

# %%
df.isnull().sum()
# Out:
# timeOpen      0
# timeClose     0
# timeHigh      0
# timeLow       0
# priceOpen     0
# priceHigh     0
# priceLow      0
# priceClose    0
# volume        0
# dtype: int64

# %%
cols_to_clean = ['priceOpen', 'priceHigh', 'priceLow', 'priceClose', 'volume']
for col in cols_to_clean:
    df[col] = df[col].astype(str).str.replace(",", ".").astype(float)

# %%
x = df['priceOpen'].values.reshape(-1, 1)
y = df['priceClose'].values.reshape(-1, 1)
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.3,random_state=42)
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score
y_pred = model.predict(x_test)
mse=mean_squared_error(y_test, y_pred)
r2=r2_score(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
print(f'R^2 Score: {r2}')
# Out:
# Mean Squared Error: 3.4427148919993234e-05
# R^2 Score: 0.9587038368974332
